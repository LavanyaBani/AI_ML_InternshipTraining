# %%
import cv2
print(cv2.__version__)
# Out:
# 5.0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
image = np.zeros((16,6), dtype='uint8')
plt.imshow(image, cmap='grey')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
image = np.zeros((16,6), dtype='uint8')
image[4:10]=1
plt.imshow(image, cmap='gray')
plt.show()

# %%
image= np.full((18,30,3), 5, dtype='uint8')
image[0:6,0:30] = [255,119,34]
image[6:12,0:30] = [255,255,255]
image[12:18,0:30] = [0,128,0]

plt.imshow(image, cmap='jet')
plt.show()

# %%
#from google.colab.patches import cv2_imshow
image= np.full((18,30,3),5 , dtype='uint8')#value after 18,30,3 was 999 i changed it to 5 since it wasn't running, 5 rund idk why
image[0:6,0:30] = [34,119,255]
image[6:12,0:30] = [255,255,255]
image[12:18,0:30] = [0,128,0]
cv2.imshow('image',image)# without colab cv2.imshow('image',image)
#cv2.imwrite('image.jpg',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
image= cv2.imread('demo.jpg')
print(type(image))
cv2.imshow('image', image)

#cv2_imshow(image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.resize(image, (100,100))
image = cv2.flip(image,0)
#r, b, g= cv2.split(image)
print(image.shape)
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (100, 100)

# %%
image=cv2.imread('demo.jpg',0)

image=cv2.GaussianBlur(image, (5,5),0)
threshold_image, th=cv2.threshold(image,157,255, cv2.THRESH_TOZERO)
th= cv2.putText(th,'Threshold Image',(200,500), cv2.FONT_HERSHEY_SIMPLEX,1,(25,255,25),2)
th= cv2.circle(th,(300,300),100,(255,0,0),5)
cv2.imshow('image',th) 
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
edge_detected_image=cv2.Canny(image,100,200)
cv2.imshow('image', edge_detected_image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
import cv2

cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
print(cascade_path)

model = cv2.CascadeClassifier(cascade_path)

print(model.empty())
# Out:
# d:\SRCEM\AI_ML_InternshipTraining\opencv\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 6
#       2
#       3 cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
#       4 print(cascade_path)
#       5
# ----> 6 model = cv2.CascadeClassifier(cascade_path)
#       7
#       8 print(model.empty())
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
import cv2
import numpy as np
image= cv2.imread("lio2.jpg")

model = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces= model.detectMultiScale(image)
print(faces)

for face in faces:
  x,y,w,h = face
  cv2.rectangle(image, (x,y), (x+w,y+h), (255,0,0),3)
cv2.imwrite("lio2ans.jpg", image)#check why blue box not appearing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 import cv2
#       2 import numpy as np
#       3 image= cv2.imread("lio2.jpg")
#       4
# ----> 5 model = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
#       6 faces= model.detectMultiScale(image)
#       7 print(faces)
#       8
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
import cv2

print(cv2)
print(cv2.__file__)
print(cv2.__version__)
# Out:
# <module 'cv2' from 'd:\\SRCEM\\AI_ML_InternshipTraining\\opencv_venv\\Lib\\site-packages\\cv2\\__init__.py'>
# d:\SRCEM\AI_ML_InternshipTraining\opencv_venv\Lib\site-packages\cv2\__init__.py
# 5.0.0

# %%
import cv2

print(cv2.__file__)
print(cv2.__version__)
import numpy as np
image= cv2.imread('lio2.jpg')
face_detector1=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_detector1=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")
faces= face_detector1.detectMultiScale(image)
eyes= eye_detector1.detectMultiScale(image)
for x,y,w,h in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),3)
    face= image[y:y+h,x:x+w]
for x,y,w,h in eyes:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),3)
    eye= image[y:y+h,x:x+w]
cv2.imwrite("lio2ans2.jpg", image)
#cv2.waitKey(5000)

# %%
#for multiple image
image1= cv2.imread("two_face.jpg")

model = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces= model.detectMultiScale(image1)
print(faces)

# %%
import cv2
print(cv2.__file__)
print(cv2.__version__)
import numpy as np
image1= cv2.imread('two_face.jpg')
face_detector1=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_detector1=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")
faces= face_detector1.detectMultiScale(image1)
eyes= eye_detector1.detectMultiScale(image1)
for x,y,w,h in faces:
    cv2.rectangle(image1,(x,y),(x+w,y+h),(255,0,0),3)
    face= image1[y:y+h,x:x+w]
for x,y,w,h in eyes:
    cv2.rectangle(image1,(x,y),(x+w,y+h),(0,0,255),3)
    eye= image1[y:y+h,x:x+w]
cv2.imwrite("two_faceans.jpg", image1
