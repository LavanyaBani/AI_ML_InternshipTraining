# %%
! pip install ultralytics

# %%
import ultralytics as ut

# %%
import cv2
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
predict_class=[0,14]
img= 'multi_human.jpg'
pred = model(img ,classes=predict_class ,conf=0.4)
pred_img=pred[0].plot()
cv2.imwrite("ans.jpg",pred_img)

#hw road obstale detect person, animal, bird...or count no of students in class in different timeline
#or simply count no of persons in an image
#search at which no what will be detected from repo rcland12
